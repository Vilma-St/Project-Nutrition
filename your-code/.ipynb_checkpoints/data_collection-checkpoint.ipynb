# %%
# Importing libraries

# import sys
# !{sys.executable} -m pip install --upgrade certifi

import requests
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep
from random import randint
import time
from IPython.core.display import clear_output
from warnings import warn
from urllib.request import Request, urlopen

# %%
# A function to obtain the list of links to individual recipes depending on cuisine, 
# in order of appearance on the website.

def GetRecipeLinks(cuisine):
    lst = []
    # Scrape 4 pages, 24 recipes on each page
    pages = range(1, 5)
    for i in pages:
        basic_url = 'https://www.deliciousmagazine.co.uk/cuisine/'
        url = basic_url + cuisine + '-recipes/page/' + str(i) +'/'
        # Request, pretending to be Mozilla browser
        req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
        html = urlopen(req, timeout=20).read()
        
        soup = BeautifulSoup(html, "lxml")
        sub_soup = soup.find_all('div', {'class': "recipe-card card-bg"})
        
        page_list = [i.find('a')['href'] for i in sub_soup]
        lst.append(page_list)

        # Pause the loop to be polite to the website
        sleep(randint(7,18))

    # Expand the list
    lst = [i for j in lst for i in j]
    return lst

# %%
lst_spanish = GetRecipeLinks('spanish')
print(len(lst_spanish))
# Out:
# 120

# %%
lst_italian = GetRecipeLinks('italian')
print(len(lst_italian))
# Out:
# 96

# %%
lst_moroccan = GetRecipeLinks('moroccan')
print(len(lst_moroccan))
# Out:
# 96

# %%
lst_indian = GetRecipeLinks('indian')
print(len(lst_indian))
# Out:
# 96

# %%
lst_mexican = GetRecipeLinks('mexican')
print(len(lst_mexican))
# Out:
# 96

# %%
# Save the lists of links to csv files in case I need them, and to avoid scraping 
# the website again.

links = [lst_spanish, lst_italian, lst_moroccan, lst_indian, lst_mexican]
cuisine = ["Spanish", "Italian", "Morroccan", "Indian", "Mexican"]

for i in range(len(cuisine)):
    df = pd.DataFrame(links[i])
    name = "../data/links_"+cuisine[i]+".csv"
    df.to_csv(name)

# %%
# What if I want to go vegan during quarantine?

# https://www.deliciousmagazine.co.uk/dietary_requirements/vegan/
# By tweaking a bit the url formation I extracted the list of 96 vegan links and saved 
# them in a separate csv

# %%
# THE LOOP WITH RANDOM PAUSE TO SCRAPE POLITELY

# Sometimes the nutrition values list length is wrong when converting to dataframe, but I
# did not have time to fix this bug. The code is good enough to collect sufficient data for
# further analysis.

def ScrapeParse(list_to_use):
    # Redeclaring the lists to store data in
    titles = []
    ingred_lists = []
    nutrition_lists = []

    # Preparing to monitor the loop
    start_time = time.time()
    requestss = 0

    # Launching the loop
    for recipe in range(len(list_to_use)):
        url = list_to_use[recipe]
        # Make a request, pretend to be Mozilla browser
        req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
        html = urlopen(req, timeout=20).read()

        soup = BeautifulSoup(html, "lxml")

        # Pause the loop
        sleep(randint(11,29))
        
        # Monitor the requests
        requestss += 1
        elapsed_time = time.time() - start_time
        print('Request:{}; Frequency: {} requests/s'.format(requestss, requestss/elapsed_time))
        # clear_output(wait = True)

        # Break the loop if the number of requests is greater than expected
        if requestss > len(list_to_use):
            warn('Number of requests was greater than expected.')
            break

        # Parse the retrieved content
        soup = BeautifulSoup(html, "lxml")

        # NUTRITIONAL VALUES
        sub_soup1 = soup.find('dl', {'class':"list-two-column style-lined"})
        # TEST FOR EMPTY
        if sub_soup1 == None:
            print("Nutritional values not found")
            nutrition = ["NaN", "NaN", "NaN", "NaN", "NaN", "NaN", "NaN", "NaN"]
        else:
            sub_soup1 = soup.find('dl', {'class':"list-two-column style-lined"}).find_all("dd")

            nutr = [i.text for i in sub_soup1]

            # Columns should be: Kcal, Fat, SaturatedFat, Protein, Carbohydrates, Sugars, Fibre, Salt 
            # Split Fats and Carbs
            nutrition = [i.split('(') for i in nutr]

            # Removing unwanted characters
            nutrition = [i.replace(")", "") for j in nutrition for i in j]
            nutrition = [i.replace("kcals", "") for i in nutrition]
            nutrition = [i.replace(" sugars", "") for i in nutrition]
            nutrition = [i.replace(" protein", "") for i in nutrition]
            nutrition = [i.replace("sugar", "") for i in nutrition]
            nutrition = [i.replace("g", "") for i in nutrition]
            nutrition = [i.replace(" saturated", "") for i in nutrition]
            nutrition = [i.replace(" satrurated", "") for i in nutrition]
            nutrition = [i.replace(" fat", "") for i in nutrition]
            nutrition = [i.replace("Trace", "") for i in nutrition]
            if len(nutrition) < 8:
                nutrition = ["NaN", "NaN", "NaN", "NaN", "NaN", "NaN", "NaN", "NaN"]
            else:
                nutrition = [i.strip() for i in nutrition]
            
        # LIST OF INGREDIENTS
        sub_soup2 = soup.find('div', {'class':"recipe-ingredients text-standard"})
        # TEST FOR EMPTY
        if sub_soup2 == None:
            print("Ingredients not found")
            ingredients = "NaN"
        else:
            sub_soup2 = soup.find('div', {'class':"recipe-ingredients text-standard"}).find_all("li")
            ingred = [i.text for i in sub_soup2]
            ingredients = ", ".join(ingred)

        # RECIPE TITLE
        title = soup.find('h1').text
        
        ingred_lists.append(ingredients)
        titles.append(title)
        nutrition_lists.append(nutrition)

    return titles, ingred_lists, nutrition_lists

# %%
# Function to save the scraped data into files

# links = [lst_spanish, lst_italian, lst_moroccan, lst_indian, lst_mexican]
# cuisine = ["Spanish", "Italian", "Morroccan", "Indian", "Mexican"]

def SaveToCsv(cuisine, recipe_list):
    j = round(len(recipe_list))
    i = 0
    for k in range(j):
        titles, ingred_lists, nutrition_lists = ScrapeParse(recipe_list[i:i+20])
        df = pd.DataFrame()
        df["Title"] = titles
        df["Ingredients"] = ingred_lists
        df[["Kcal", "Fat", "SaturatedFat", "Protein", "Carbohydrates", "Sugars", "Fibre", "Salt"]] = pd.DataFrame(nutrition_lists)
        df["Country"] = cuisine
        # Saving dataframe to csv file
        name = "../data/recipes_"+cuisine+str(k)+".csv"
        df.to_csv(name)
        i += 20

# %%
# Creating the dataframes for Spanish data.
# Scraping and saving batches of 20 recipes at a time. It is easier to prevent already 
# scraped data loss, monitor and spot errors this way.
# 120 Spanish recipes

cuisine_name = "Spain"

SaveToCsv(cuisine_name, lst_spanish)
# Out:
# Request:1; Frequency: 0.0813509469483251 requests/s
# Request:2; Frequency: 0.05281190382173646 requests/s
# Request:3; Frequency: 0.05150055717624027 requests/s
# Request:4; Frequency: 0.0525153796447619 requests/s
# Request:5; Frequency: 0.0546449807462451 requests/s
# Request:6; Frequency: 0.051795073890554974 requests/s
# Request:7; Frequency: 0.05296305278369173 requests/s
# Request:8; Frequency: 0.054175576510788984 requests/s
# Nutritional values not found
# Request:9; Frequency: 0.05172219330516067 requests/s
# Nutritional values not found
# Request:10; Frequency: 0.05015903723001508 requests/s
# Request:11; Frequency: 0.04939791175105149 requests/s
# Request:12; Frequency: 0.05020379389767321 requests/s
# Request:13; Frequency: 0.04834764069401712 requests/s
# Request:14; Frequency: 0.049574069338411554 requests/s
# Request:15; Frequency: 0.04811676468767325 requests/s
# Request:16; Frequency: 0.0492155251674045 requests/s
# Nutritional values not found
# Request:17; Frequency: 0.050362918917010405 requests/s
# Request:18; Frequency: 0.049233505170323696 requests/s
# Request:19; Frequency: 0.04835048245185833 requests/s
# Request:20; Frequency: 0.04780083465433828 requests/s
# Request:1; Frequency: 0.034167712091107034 requests/s
# Request:2; Frequency: 0.040325070153349865 requests/s
# Request:3; Frequency: 0.04550959626441543 requests/s
# Nutritional values not found
# Request:4; Frequency: 0.044904504054338455 requests/s
# Request:5; Frequency: 0.04484085189356676 requests/s
# Request:6; Frequency: 0.044989556159085335 requests/s
# Request:7; Frequency: 0.046122783136198435 requests/s
# Request:8; Frequency: 0.04696961355412995 requests/s
# Nutritional values not found
# Request:9; Frequency: 0.045175432495740284 requests/s
# Nutritional values not found
# Request:10; Frequency: 0.04585083104270519 requests/s
# Request:11; Frequency: 0.04471994225510844 requests/s
# Request:12; Frequency: 0.04324408414630759 requests/s
# Request:13; Frequency: 0.0445451025184755 requests/s
# Request:14; Frequency: 0.0451992607342134 requests/s
# Request:15; Frequency: 0.04516382631244187 requests/s
# Request:16; Frequency: 0.04515815773588251 requests/s
# Request:17; Frequency: 0.04604446630131315 requests/s
# Request:18; Frequency: 0.04606539706669403 requests/s
# Request:19; Frequency: 0.045658592924188696 requests/s
# Request:20; Frequency: 0.04493638833250733 requests/s
# Request:1; Frequency: 0.0698598626781897 requests/s
# Request:2; Frequency: 0.04741922742978835 requests/s
# Request:3; Frequency: 0.046462578440489836 requests/s
# Request:4; Frequency: 0.04401562808839364 requests/s
# Request:5; Frequency: 0.04238342009478497 requests/s
# Nutritional values not found
# Request:6; Frequency: 0.04156894725660365 requests/s
# Request:7; Frequency: 0.0424411190295833 requests/s
# Request:8; Frequency: 0.04364649346005377 requests/s
# Request:9; Frequency: 0.04586625903372143 requests/s
# Request:10; Frequency: 0.04659039251771206 requests/s
# Request:11; Frequency: 0.04540194410350187 requests/s
# Request:12; Frequency: 0.04424399112191678 requests/s
# Request:13; Frequency: 0.0448418412778233 requests/s
# Request:14; Frequency: 0.04601464118689949 requests/s
# Nutritional values not found
# Request:15; Frequency: 0.047057262186466796 requests/s
# Request:16; Frequency: 0.04640851207734408 requests/s
# Request:17; Frequency: 0.046470038804883824 requests/s
# Nutritional values not found
# Request:18; Frequency: 0.04668783538030912 requests/s
# Request:19; Frequency: 0.04714972362866751 requests/s
# Request:20; Frequency: 0.046569747150280304 requests/s
# Request:1; Frequency: 0.053369208821924474 requests/s
# Request:2; Frequency: 0.03744600993003527 requests/s
# Request:3; Frequency: 0.03960403207054529 requests/s
# Request:4; Frequency: 0.037866420670136514 requests/s
# Request:5; Frequency: 0.04064064682910829 requests/s
# Nutritional values not found
# Request:6; Frequency: 0.03987747726595917 requests/s
# Request:7; Frequency: 0.04092097019746399 requests/s
# Request:8; Frequency: 0.04234055076778794 requests/s
# Request:9; Frequency: 0.04319064190676344 requests/s
# Request:10; Frequency: 0.04551393059441359 requests/s
# Nutritional values not found
# Request:11; Frequency: 0.04398513905035299 requests/s
# Request:12; Frequency: 0.04341501115595985 requests/s
# Request:13; Frequency: 0.04302607695276426 requests/s
# Request:14; Frequency: 0.04235433340194124 requests/s
# Request:15; Frequency: 0.0436831471285923 requests/s
# Request:16; Frequency: 0.042547197304606224 requests/s
# Nutritional values not found
# Request:17; Frequency: 0.0434110278541705 requests/s
# Request:18; Frequency: 0.043267226248119316 requests/s
# Request:19; Frequency: 0.043638593575101796 requests/s
# Request:20; Frequency: 0.042481520825732415 requests/s
# Request:1; Frequency: 0.03312277075191769 requests/s
# Request:2; Frequency: 0.032850319178536196 requests/s
# Request:3; Frequency: 0.033581413367159196 requests/s
# Request:4; Frequency: 0.03410553834652177 requests/s
# Request:5; Frequency: 0.034350522788201734 requests/s
# Request:6; Frequency: 0.034538671922122524 requests/s
# Request:7; Frequency: 0.03515032652218313 requests/s
# Nutritional values not found
# Request:8; Frequency: 0.036269780349497 requests/s
# Nutritional values not found
# Request:9; Frequency: 0.037292539423223935 requests/s
# Request:10; Frequency: 0.03630012065055345 requests/s
# Request:11; Frequency: 0.03691716128908693 requests/s
# Request:12; Frequency: 0.037589252236037124 requests/s
# Request:13; Frequency: 0.03744664172495803 requests/s
# Request:14; Frequency: 0.0379527517653259 requests/s
# Request:15; Frequency: 0.038389364173233104 requests/s
# Request:16; Frequency: 0.03908866410781102 requests/s
# Request:17; Frequency: 0.040171156068369705 requests/s
# Request:18; Frequency: 0.03926389779624858 requests/s
# Request:19; Frequency: 0.03992597521423742 requests/s
# Request:20; Frequency: 0.040423228027821424 requests/s
# Request:1; Frequency: 0.04806901981731498 requests/s
# Request:2; Frequency: 0.04397032987329181 requests/s
# Nutritional values not found
# Request:3; Frequency: 0.03998211732246705 requests/s
# Nutritional values not found
# Request:4; Frequency: 0.044164220046355486 requests/s
# Request:5; Frequency: 0.042968766767450865 requests/s
# Nutritional values not found
# Request:6; Frequency: 0.04311547102728276 requests/s
# Request:7; Frequency: 0.0400704587358303 requests/s
# Request:8; Frequency: 0.04197312665198259 requests/s
# Request:9; Frequency: 0.0433584958748167 requests/s
# Request:10; Frequency: 0.0432877848184237 requests/s
# Nutritional values not found
# Request:11; Frequency: 0.04253272279401862 requests/s
# Request:12; Frequency: 0.042248924927447404 requests/s
# Request:13; Frequency: 0.04370763254772275 requests/s
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# <ipython-input-152-99d0139454bb> in <module>
#       7
#       8 for k in range(j):
# ----> 9     titles, ingred_lists, nutrition_lists = ScrapeParse(lst_spanish[i:i+20])
#      10     df = pd.DataFrame()
#      11     df["Title"] = titles
#
# <ipython-input-115-6cef5e9d08ab> in ScrapeParse(list_to_use)
#      17 #         html = requests.get(url, timeout=30).content
#      18         req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
# ---> 19         html = urlopen(req, timeout=20).read()
#      20
#      21         soup = BeautifulSoup(html, "lxml")
#
# /usr/local/opt/python/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/local/opt/python/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /usr/local/opt/python/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# /usr/local/opt/python/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /usr/local/opt/python/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in https_open(self, req)
#    1360         def https_open(self, req):
#    1361             return self.do_open(http.client.HTTPSConnection, req,
# -> 1362                 context=self._context, check_hostname=self._check_hostname)
#    1363
#    1364         https_request = AbstractHTTPHandler.do_request_
#
# /usr/local/opt/python/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1320             except OSError as err: # timeout error
#    1321                 raise URLError(err)
# -> 1322             r = h.getresponse()
#    1323         except:
#    1324             h.close()
#
# /usr/local/opt/python/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# /usr/local/opt/python/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# /usr/local/opt/python/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# /usr/local/opt/python/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/local/opt/python/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/local/opt/python/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# timeout: The read operation timed out

# %%
# Creating the dataframes for Italian data.
# Scraping and saving batches of 20 recipes at a time.
# 96 Italian recipes

cuisine_name = "Italy"

SaveToCsv(cuisine_name, lst_italian)
# Out:
# 11

# %%
# Creating the dataframes for Indian data.
# Scraping and saving batches of 20 recipes at a time.
# 96 Indian recipes

cuisine_name = "India"

SaveToCsv(cuisine_name, lst_indian)
# Out:
# Request:1; Frequency: 0.08819782469545148 requests/s
# Request:2; Frequency: 0.04938002538377884 requests/s
# Request:3; Frequency: 0.043423476886998276 requests/s
# Request:4; Frequency: 0.04936736145034327 requests/s
# Request:5; Frequency: 0.04837521773786648 requests/s
# Request:6; Frequency: 0.048752420212520506 requests/s
# Request:7; Frequency: 0.04662254090015631 requests/s
# Request:8; Frequency: 0.046317740198117865 requests/s
# Request:9; Frequency: 0.046094186791386826 requests/s
# Request:10; Frequency: 0.046714685325650054 requests/s
# Request:11; Frequency: 0.0451029548628093 requests/s
# Request:12; Frequency: 0.044431037631217536 requests/s
# Request:13; Frequency: 0.04516069692708792 requests/s
# Request:14; Frequency: 0.04512931724115179 requests/s
# Request:15; Frequency: 0.04515931232593566 requests/s
# Request:16; Frequency: 0.046180368615808806 requests/s
# Request:17; Frequency: 0.04589387278265174 requests/s
# Request:18; Frequency: 0.04670988554346093 requests/s
# Request:19; Frequency: 0.0477883692296633 requests/s
# Request:20; Frequency: 0.04718863803310852 requests/s
# Nutritional values not found
# Request:1; Frequency: 0.03368215337832447 requests/s
# Request:2; Frequency: 0.04326132393830943 requests/s
# Request:3; Frequency: 0.040746090716684225 requests/s
# Request:4; Frequency: 0.03911517671395913 requests/s
# Request:5; Frequency: 0.036958277534256186 requests/s
# Request:6; Frequency: 0.038775349775984964 requests/s
# Request:7; Frequency: 0.04114948909172655 requests/s
# Request:8; Frequency: 0.04359755630800268 requests/s
# Request:9; Frequency: 0.04301563063961635 requests/s
# Request:10; Frequency: 0.04208421887696107 requests/s
# Request:11; Frequency: 0.040324560499282736 requests/s
# Request:12; Frequency: 0.039227540295818236 requests/s
# Request:13; Frequency: 0.040501717679240025 requests/s
# Request:14; Frequency: 0.03993802201001459 requests/s
# Request:15; Frequency: 0.041312204835479815 requests/s
# Request:16; Frequency: 0.041518201345936215 requests/s
# Request:17; Frequency: 0.04280322552961111 requests/s
# Request:18; Frequency: 0.042699198686227784 requests/s
# Request:19; Frequency: 0.04156610931059676 requests/s
# Request:20; Frequency: 0.04096748658813377 requests/s
# Request:1; Frequency: 0.034128617873744625 requests/s
# Request:2; Frequency: 0.039110795014852165 requests/s
# Nutritional values not found
# Request:3; Frequency: 0.043423302757473206 requests/s
# Request:4; Frequency: 0.04163283096625435 requests/s
# Request:5; Frequency: 0.0411117982489439 requests/s
# Nutritional values not found
# Request:6; Frequency: 0.04505636288558936 requests/s
# Request:7; Frequency: 0.04318518002163909 requests/s
# Request:8; Frequency: 0.04178271429350297 requests/s
# Request:9; Frequency: 0.04169298484099887 requests/s
# Request:10; Frequency: 0.041455278437562 requests/s
# Request:11; Frequency: 0.04250364558144522 requests/s
# Request:12; Frequency: 0.04267694996046665 requests/s
# Request:13; Frequency: 0.04256384862960988 requests/s
# Request:14; Frequency: 0.04212818978310907 requests/s
# Request:15; Frequency: 0.042176376529275396 requests/s
# Request:16; Frequency: 0.04241702517729008 requests/s
# Request:17; Frequency: 0.04303709108216662 requests/s
# Request:18; Frequency: 0.04396758804706046 requests/s
# Request:19; Frequency: 0.04430579065351997 requests/s
# Request:20; Frequency: 0.04442198687777581 requests/s
# Request:1; Frequency: 0.03706533036835717 requests/s
# Request:2; Frequency: 0.036127175477951294 requests/s
# Request:3; Frequency: 0.035406648383505664 requests/s
# Request:4; Frequency: 0.04112485988447684 requests/s
# Request:5; Frequency: 0.03949425057272918 requests/s
# Request:6; Frequency: 0.03866416920751001 requests/s
# Request:7; Frequency: 0.03964772855075204 requests/s
# Request:8; Frequency: 0.0397163620214485 requests/s
# Request:9; Frequency: 0.04114500891654188 requests/s
# Request:10; Frequency: 0.04113102065503197 requests/s
# Request:11; Frequency: 0.04066296978509779 requests/s
# Request:12; Frequency: 0.041748700841301264 requests/s
# Request:13; Frequency: 0.04192199257990996 requests/s
# Request:14; Frequency: 0.041533046090520505 requests/s
# Request:15; Frequency: 0.041963839432966735 requests/s
# Request:16; Frequency: 0.02159296414503834 requests/s
# Request:17; Frequency: 0.02190692344048386 requests/s
# Request:18; Frequency: 0.02251553566721751 requests/s
# Request:19; Frequency: 0.02312780348570887 requests/s
# Nutritional values not found
# Request:20; Frequency: 0.023857249496836153 requests/s
# Nutritional values not found
# Request:1; Frequency: 0.052802773664373914 requests/s
# Request:2; Frequency: 0.04498611615531104 requests/s
# Request:3; Frequency: 0.0441820755117366 requests/s
# Nutritional values not found
# Request:4; Frequency: 0.050319308598506855 requests/s
# Request:5; Frequency: 0.04857977747279466 requests/s
# Request:6; Frequency: 0.04915309058419734 requests/s
# Request:7; Frequency: 0.050277785523289556 requests/s
# Request:8; Frequency: 0.049917717829288936 requests/s
# Request:9; Frequency: 0.049670801496929394 requests/s
# Request:10; Frequency: 0.049970282882320104 requests/s
# Request:11; Frequency: 0.05171254093698231 requests/s
# Request:12; Frequency: 0.05049537835540058 requests/s
# Request:13; Frequency: 0.04965633742601446 requests/s
# Request:14; Frequency: 0.05009643239658481 requests/s
# Request:15; Frequency: 0.05156384427089195 requests/s
# Request:16; Frequency: 0.052582395889673526 requests/s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-180-93879e57fda8> in <module>
#      11     df["Title"] = titles
#      12     df["Ingredients"] = ingred_lists
# ---> 13     df[["Kcal", "Fat", "SaturatedFat", "Protein", "Carbohydrates", "Sugars", "Fibre", "Salt"]] = pd.DataFrame(nutrition_lists)
#      14     df["Country"] = "India"
#      15     # Saving dataframe to csv file
#
# /usr/local/Cellar/jupyterlab/2.0.1/libexec/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2933             self._setitem_frame(key, value)
#    2934         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 2935             self._setitem_array(key, value)
#    2936         else:
#    2937             # set column
#
# /usr/local/Cellar/jupyterlab/2.0.1/libexec/lib/python3.7/site-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    2959             if isinstance(value, DataFrame):
#    2960                 if len(value.columns) != len(key):
# -> 2961                     raise ValueError("Columns must be same length as key")
#    2962                 for k1, k2 in zip(key, value.columns):
#    2963                     self[k1] = value[k2]
#
# ValueError: Columns must be same length as key

# %%
# Creating the dataframes for Mexican data.
# Scraping and saving batches of 20 recipes at a time.
# 96 recipes

cuisine_name = "Mexican"

SaveToCsv(cuisine_name, lst_mexican)
# Out:
# Request:1; Frequency: 0.05168645204040834 requests/s
# Request:2; Frequency: 0.047750228982980404 requests/s
# Request:3; Frequency: 0.042959844678129626 requests/s
# Request:4; Frequency: 0.045472724257004445 requests/s
# Request:5; Frequency: 0.044105520064249996 requests/s
# Request:6; Frequency: 0.042255965425130056 requests/s
# Request:7; Frequency: 0.04441494621775857 requests/s
# Request:8; Frequency: 0.04646252759334787 requests/s
# Request:9; Frequency: 0.045551631875425797 requests/s
# Request:10; Frequency: 0.044564083571838824 requests/s
# Nutritional values not found
# Request:11; Frequency: 0.0464468005462128 requests/s
# Request:12; Frequency: 0.045245570075817615 requests/s
# Request:13; Frequency: 0.046327533585380054 requests/s
# Nutritional values not found
# Request:14; Frequency: 0.04791138384326254 requests/s
# Request:15; Frequency: 0.047293034834047 requests/s
# Request:16; Frequency: 0.046090753283032075 requests/s
# Request:17; Frequency: 0.045931187901703495 requests/s
# Request:18; Frequency: 0.04474486612189444 requests/s
# Request:19; Frequency: 0.04525396992038325 requests/s
# Nutritional values not found
# Request:20; Frequency: 0.04625842168570771 requests/s
# Request:1; Frequency: 0.04108784821019357 requests/s
# Request:2; Frequency: 0.05116119911426793 requests/s
# Request:3; Frequency: 0.05587404159618142 requests/s
# Request:4; Frequency: 0.0553310145967023 requests/s
# Nutritional values not found
# Request:5; Frequency: 0.058783152868445966 requests/s
# Request:6; Frequency: 0.056986716162260614 requests/s
# Request:7; Frequency: 0.05870361704678426 requests/s
# Request:8; Frequency: 0.058077422850916376 requests/s
# Request:9; Frequency: 0.05446819521487477 requests/s
# Request:10; Frequency: 0.05425225890763378 requests/s
# Request:11; Frequency: 0.05192934439178844 requests/s
# Request:12; Frequency: 0.05125990151037452 requests/s
# Request:13; Frequency: 0.05147574183516494 requests/s
# Request:14; Frequency: 0.0530291460399021 requests/s
# Request:15; Frequency: 0.05141928433368862 requests/s
# Request:16; Frequency: 0.05031203397933324 requests/s
# Request:17; Frequency: 0.049478790573944754 requests/s
# Request:18; Frequency: 0.049160675675047665 requests/s
# Request:19; Frequency: 0.04934569466480202 requests/s
# Request:20; Frequency: 0.04880525111140856 requests/s
# Request:1; Frequency: 0.04678097551385272 requests/s
# Request:2; Frequency: 0.04183013273317859 requests/s
# Request:3; Frequency: 0.04000178357765344 requests/s
# Request:4; Frequency: 0.03653015982354268 requests/s
# Nutritional values not found
# Request:5; Frequency: 0.03473727604433297 requests/s
# Request:6; Frequency: 0.037076256900013184 requests/s
# Request:7; Frequency: 0.0353946707508531 requests/s
# Request:8; Frequency: 0.03704393271388007 requests/s
# Request:9; Frequency: 0.03632914676214285 requests/s
# Request:10; Frequency: 0.03513600614960528 requests/s
# Request:11; Frequency: 0.036662251548527355 requests/s
# Request:12; Frequency: 0.03830488880795446 requests/s
# Request:13; Frequency: 0.03884474276882332 requests/s
# Request:14; Frequency: 0.03829646386805464 requests/s
# Request:15; Frequency: 0.03820268694592373 requests/s
# Request:16; Frequency: 0.03875200852242176 requests/s
# Request:17; Frequency: 0.03844384236801425 requests/s
# Request:18; Frequency: 0.038226301001036044 requests/s
# Request:19; Frequency: 0.03808385837337883 requests/s
# Request:20; Frequency: 0.037831690715339185 requests/s
# Request:1; Frequency: 0.04910246117905851 requests/s
# Request:2; Frequency: 0.04083753604595781 requests/s
# Request:3; Frequency: 0.04060337639490861 requests/s
# Request:4; Frequency: 0.045174842348911635 requests/s
# Request:5; Frequency: 0.043891910895238376 requests/s
# Request:6; Frequency: 0.04207940750736492 requests/s
# Request:7; Frequency: 0.04526004659165425 requests/s
# Request:8; Frequency: 0.04746128909413874 requests/s
# Request:9; Frequency: 0.048481331418638064 requests/s
# Request:10; Frequency: 0.04779839996800725 requests/s
# Request:11; Frequency: 0.048462648257209 requests/s
# Request:12; Frequency: 0.04676621813905646 requests/s
# Request:13; Frequency: 0.047387070742969245 requests/s
# Request:14; Frequency: 0.04606401315103015 requests/s
# Nutritional values not found
# Request:15; Frequency: 0.046514330502278795 requests/s
# Nutritional values not found
# Request:16; Frequency: 0.04544136861345532 requests/s
# Request:17; Frequency: 0.04558263557079608 requests/s
# Request:18; Frequency: 0.0454029825593691 requests/s
# Request:19; Frequency: 0.04582675719071841 requests/s
# Request:20; Frequency: 0.04682737650728517 requests/s
# Request:1; Frequency: 0.03788256882715993 requests/s
# Request:2; Frequency: 0.04091189576100179 requests/s
# Nutritional values not found
# Request:3; Frequency: 0.04091869729032593 requests/s
# Request:4; Frequency: 0.04299948444340869 requests/s
# Request:5; Frequency: 0.04107990317089283 requests/s
# Request:6; Frequency: 0.03962271274358438 requests/s
# Request:7; Frequency: 0.04025549028198311 requests/s
# Request:8; Frequency: 0.04093503332741499 requests/s
# Request:9; Frequency: 0.042069344278145404 requests/s
# Request:10; Frequency: 0.04160393555734577 requests/s
# Request:11; Frequency: 0.04077498174655538 requests/s
# Request:12; Frequency: 0.04036574715179495 requests/s
# Request:13; Frequency: 0.04079052834689415 requests/s
# Nutritional values not found
# Request:14; Frequency: 0.04002192000271526 requests/s
# Request:15; Frequency: 0.040486342242821036 requests/s
# Request:16; Frequency: 0.04130808996701711 requests/s
# Nutritional values not found
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-182-346302cc8c91> in <module>
#      11     df["Title"] = titles
#      12     df["Ingredients"] = ingred_lists
# ---> 13     df[["Kcal", "Fat", "SaturatedFat", "Protein", "Carbohydrates", "Sugars", "Fibre", "Salt"]] = pd.DataFrame(nutrition_lists)
#      14     df["Country"] = "Mexico"
#      15     # Saving dataframe to csv file
#
# /usr/local/Cellar/jupyterlab/2.0.1/libexec/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2933             self._setitem_frame(key, value)
#    2934         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 2935             self._setitem_array(key, value)
#    2936         else:
#    2937             # set column
#
# /usr/local/Cellar/jupyterlab/2.0.1/libexec/lib/python3.7/site-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    2959             if isinstance(value, DataFrame):
#    2960                 if len(value.columns) != len(key):
# -> 2961                     raise ValueError("Columns must be same length as key")
#    2962                 for k1, k2 in zip(key, value.columns):
#    2963                     self[k1] = value[k2]
#
# ValueError: Columns must be same length as key

# %%
# Creating the dataframes for vegan data.
# Scraping and saving batches of 20 recipes at a time.
# 96 recipes

lst_vegan = pd.read_csv("../data/links_vegan.csv")
lst_vegan = lst_vegan.values.tolist()
lst_vegan = [i for j in lst_vegan for i in j]

cuisine_name = "vegan"

SaveToCsv(cuisine_name, lst_vegan)
# Out:
# Request:1; Frequency: 0.05308783503856044 requests/s
# Request:2; Frequency: 0.04607589757463959 requests/s
# Request:3; Frequency: 0.043502192661713394 requests/s
# Nutritional values not found
# Request:4; Frequency: 0.042328961395187395 requests/s
# Request:5; Frequency: 0.041698949279143735 requests/s
# Request:6; Frequency: 0.04158171987264154 requests/s
# Request:7; Frequency: 0.04072230428484362 requests/s
# Request:8; Frequency: 0.041821049097584884 requests/s
# Nutritional values not found
# Request:9; Frequency: 0.04263120821551376 requests/s
# Request:10; Frequency: 0.04191620784254409 requests/s
# Request:11; Frequency: 0.04129183007643905 requests/s
# Request:12; Frequency: 0.04258736994327269 requests/s
# Request:13; Frequency: 0.04372520621609999 requests/s
# Request:14; Frequency: 0.04330213925322046 requests/s
# Request:15; Frequency: 0.041878967329772435 requests/s
# Request:16; Frequency: 0.0429402804023077 requests/s
# Request:17; Frequency: 0.042290093653568006 requests/s
# Request:18; Frequency: 0.04263597218437235 requests/s
# Request:19; Frequency: 0.04256881961689111 requests/s
# Request:20; Frequency: 0.042398697123234866 requests/s
# Request:1; Frequency: 0.0452256214314487 requests/s
# Request:2; Frequency: 0.051240179005598185 requests/s
# Request:3; Frequency: 0.04472039522628495 requests/s
# Request:4; Frequency: 0.04225761296031482 requests/s
# Request:5; Frequency: 0.04440126751201343 requests/s
# Request:6; Frequency: 0.04282949949703748 requests/s
# Request:7; Frequency: 0.0423241690821214 requests/s
# Request:8; Frequency: 0.04384276532592694 requests/s
# Nutritional values not found
# Request:9; Frequency: 0.04615771060771401 requests/s
# Request:10; Frequency: 0.046102405577767805 requests/s
# Request:11; Frequency: 0.04512258308630125 requests/s
# Request:12; Frequency: 0.04684406919818706 requests/s
# Request:13; Frequency: 0.04655744925201758 requests/s
# Request:14; Frequency: 0.047984031297794445 requests/s
# Request:15; Frequency: 0.048759769594631755 requests/s
# Request:16; Frequency: 0.04854414856534603 requests/s
# Request:17; Frequency: 0.04871397386442398 requests/s
# Request:18; Frequency: 0.04828617645188429 requests/s
# Request:19; Frequency: 0.04912196036597677 requests/s
# Request:20; Frequency: 0.04812877303551635 requests/s
# Request:1; Frequency: 0.02882500781428221 requests/s
# Request:2; Frequency: 0.033296118316777916 requests/s
# Request:3; Frequency: 0.03384979702435095 requests/s
# Request:4; Frequency: 0.037897081881623516 requests/s
# Request:5; Frequency: 0.0380931678564963 requests/s
# Request:6; Frequency: 0.03692924562827481 requests/s
# Request:7; Frequency: 0.03904223880284975 requests/s
# Request:8; Frequency: 0.04008711735734339 requests/s
# Request:9; Frequency: 0.03856479557372393 requests/s
# Request:10; Frequency: 0.04049953061993528 requests/s
# Request:11; Frequency: 0.04146381703435614 requests/s
# Request:12; Frequency: 0.04141133359181782 requests/s
# Request:13; Frequency: 0.04106207240928792 requests/s
# Request:14; Frequency: 0.04106093732741082 requests/s
# Request:15; Frequency: 0.04151320091542913 requests/s
# Request:16; Frequency: 0.04091783450120679 requests/s
# Request:17; Frequency: 0.04112278310063017 requests/s
# Request:18; Frequency: 0.041024508056451275 requests/s
# Request:19; Frequency: 0.041004767907982534 requests/s
# Request:20; Frequency: 0.04212441079995367 requests/s
# Request:1; Frequency: 0.04007780722899832 requests/s
# Request:2; Frequency: 0.046431972346174064 requests/s
# Request:3; Frequency: 0.04821377759156461 requests/s
# Request:4; Frequency: 0.05055559589257118 requests/s
# Request:5; Frequency: 0.04629071179403614 requests/s
# Request:6; Frequency: 0.04480728785039899 requests/s
# Request:7; Frequency: 0.04792519997983886 requests/s
# Request:8; Frequency: 0.04412362403974576 requests/s
# Request:9; Frequency: 0.042189579165443115 requests/s
# Request:10; Frequency: 0.0433438621315846 requests/s
# Request:11; Frequency: 0.04382087970526108 requests/s
# Request:12; Frequency: 0.042241720929876395 requests/s
# Request:13; Frequency: 0.04162337475515702 requests/s
# Request:14; Frequency: 0.04318861654470989 requests/s
# Request:15; Frequency: 0.0434478376974552 requests/s
# Request:16; Frequency: 0.042310244396802706 requests/s
# Request:17; Frequency: 0.04180058294941678 requests/s
# Request:18; Frequency: 0.041749670532779296 requests/s
# Request:19; Frequency: 0.04236146699552494 requests/s
# Request:20; Frequency: 0.041773069994118166 requests/s
# Request:1; Frequency: 0.04672901080015893 requests/s
# Request:2; Frequency: 0.04196831205847225 requests/s
# Request:3; Frequency: 0.037684030898533886 requests/s
# Request:4; Frequency: 0.040580553496191475 requests/s
# Request:5; Frequency: 0.04111169807077059 requests/s
# Request:6; Frequency: 0.04268824282086397 requests/s
# Request:7; Frequency: 0.04117610752696427 requests/s
# Request:8; Frequency: 0.04140599073964484 requests/s
# Request:9; Frequency: 0.04159877725517936 requests/s
# Request:10; Frequency: 0.041563278856448636 requests/s
# Request:11; Frequency: 0.04346626450250518 requests/s
# Request:12; Frequency: 0.044290285389809496 requests/s
# Request:13; Frequency: 0.04602176777513871 requests/s
# Request:14; Frequency: 0.045930216217709055 requests/s
# Request:15; Frequency: 0.046329862263357 requests/s
# Request:16; Frequency: 0.04641685695669549 requests/s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-178-37f4fd5e8070> in <module>
#      15     df["Title"] = titles
#      16     df["Ingredients"] = ingred_lists
# ---> 17     df[["Kcal", "Fat", "SaturatedFat", "Protein", "Carbohydrates", "Sugars", "Fibre", "Salt"]] = pd.DataFrame(nutrition_lists)
#      18     df["Country"] = "vegan"
#      19     # Saving dataframe to csv file
#
# /usr/local/Cellar/jupyterlab/2.0.1/libexec/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2933             self._setitem_frame(key, value)
#    2934         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 2935             self._setitem_array(key, value)
#    2936         else:
#    2937             # set column
#
# /usr/local/Cellar/jupyterlab/2.0.1/libexec/lib/python3.7/site-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    2959             if isinstance(value, DataFrame):
#    2960                 if len(value.columns) != len(key):
# -> 2961                     raise ValueError("Columns must be same length as key")
#    2962                 for k1, k2 in zip(key, value.columns):
#    2963                     self[k1] = value[k2]
#
# ValueError: Columns must be same length as key

# %%
# Function to concatenate the dataframes from all csv files into one (by cuisine)

def ToDataFrame(cuisine, file_count, file_name):
    # Creating empty dataframe    
    result = pd.DataFrame(columns=["Title", "Ingredients", "Kcal", "Fat", "SaturatedFat", "Protein", "Carbohydrates", "Sugars", "Fibre", "Salt", "Country"])
    
    # Loop to concatenate dataframes from separate files    
    for i in range(file_count):
        df = pd.read_csv("../data/recipes_"+cuisine="_"str(i)+".csv", index_col="Unnamed: 0").reset_index(drop=True)
        result = pd.concat([result, df], ignore_index=True)
    
    # Saving result to csv file
    result.to_csv("../data/recipes_"+file_name+"_df.csv")

# %%
# Concatenate the dataframes from all csv files into one

files = 5

ToDataFrame("Italy", files, "Italian")
ToDataFrame("Spain", files, "Spanish")
ToDataFrame("vegan", files, "vegan")
ToDataFrame("India", files, "Indian")
ToDataFrame("Mexican", files, "Mexican")
